# %%
import numpy as np
import matplotlib.pyplot as plt
import moviepy.editor as mpy
import skimage.transform
from IPython.display import Image, display

import tensorflow as tf
import tensorflow_probability as tfp
import tensorflow.keras.losses as kls

# %%
gpus = tf.config.list_physical_devices("GPU") 
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"  # this line make pop-out window not appear
from ple.games.flappybird import FlappyBird
from ple import PLE

game = FlappyBird()
env = PLE(game, fps=30, display_screen=False)  # environment interface to game
env.reset_game()

test_game = FlappyBird()
test_env = PLE(test_game, fps=30, display_screen=False)
test_env.reset_game()
# Out:
# couldn't import doomish
# Couldn't import doom

# %%
path = './movie_f' 
if not os.path.exists(path):
    os.makedirs(path)

# %%
hparas = {
    'image_size': 84,
    'num_stack': 4,
    'action_dim': len(env.getActionSet()),
    'hidden_size': 256,
    'lr': 0.0001,
    'gamma': 0.99,
    'lambda': 0.95,
    'clip_val': 0.2,
    'ppo_epochs': 8,
    'test_epochs': 1,
    'num_steps': 512,
    'mini_batch_size': 64,
    'target_reward': 200,
    'max_episode': 30000,
}

# %%
# Please do not modify this method
def make_anim(images, fps=60, true_image=False):
    duration = len(images) / fps

    def make_frame(t):
        try:
            x = images[int(len(images) / duration * t)]
        except:
            x = images[-1]

        if true_image:
            return x.astype(np.uint8)
        else:
            return ((x + 1) / 2 * 255).astype(np.uint8)

    clip = mpy.VideoClip(make_frame, duration=duration)
    clip.fps = fps
    
    return clip

# %%
def preprocess_screen(screen):
    screen = skimage.transform.rotate(screen, -90, resize=True)
    screen = screen[:400, :]
    screen = skimage.transform.resize(screen, [hparas['image_size'], hparas['image_size'], 1])
    return screen.astype(np.float32)

def frames_to_state(input_frames):
    if(len(input_frames) == 1):
        state = np.concatenate(input_frames*4, axis=-1)
    elif(len(input_frames) == 2):
        state = np.concatenate(input_frames[0:1]*2 + input_frames[1:]*2, axis=-1)
    elif(len(input_frames) == 3):
        state = np.concatenate(input_frames + input_frames[2:], axis=-1)
    else:
        state = np.concatenate(input_frames[-4:], axis=-1)

    return state

# %%
class ActorCriticNetwork(tf.keras.Model):
    def __init__(self, hparas):
        super().__init__()

        self.feature_extractor = tf.keras.Sequential([
          # Convolutional Layers
          tf.keras.layers.Conv2D(filters=32, kernel_size=8, strides=4),
          tf.keras.layers.ReLU(),
          tf.keras.layers.Conv2D(filters=64, kernel_size=4, strides=2),
          tf.keras.layers.ReLU(),
          tf.keras.layers.Conv2D(filters=64, kernel_size=3, strides=1),
          tf.keras.layers.ReLU(),
          # Embedding Layers
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(hparas['hidden_size']),
          tf.keras.layers.ReLU(),
        ])

        # Actor Network
        self.actor = tf.keras.layers.Dense(hparas['action_dim'], activation='softmax')
        # Critic Network
        self.critic = tf.keras.layers.Dense(1, activation = None)

    def call(self, input):
        x = self.feature_extractor(input)
        action_logits = self.actor(x)
        value = self.critic(x)
        return action_logits, value

# %%
class Agent():
    def __init__(self, hparas):
        self.gamma = hparas['gamma']
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=hparas['lr'])
        self.actor_critic = ActorCriticNetwork(hparas)
        self.clip_pram = hparas['clip_val']
    
    def ppo_iter(self, mini_batch_size, states, actions, log_probs, returns, advantage):
        batch_size = states.shape[0]
        for _ in range(batch_size // mini_batch_size):
            rand_ids = tf.convert_to_tensor(np.random.randint(0, batch_size, mini_batch_size), dtype=tf.int32)
            yield tf.gather(states, rand_ids), tf.gather(actions, rand_ids), tf.gather(log_probs, rand_ids), \
             tf.gather(returns, rand_ids), tf.gather(advantage, rand_ids)
    
    def ppo_update(self, ppo_epochs, mini_batch_size, states, actions, log_probs, discount_rewards, advantages):       
        total_actor_loss = 0
        total_critic_loss = 0
        for _ in range(ppo_epochs):
            for state, action, old_log_probs, reward, advantage in self.ppo_iter(mini_batch_size, states, actions, log_probs, discount_rewards, advantages):
                reward = tf.expand_dims(reward, axis=-1)

                with tf.GradientTape() as tape:
                    prob, value = self.actor_critic(state, training=True)
                    dist = tfp.distributions.Categorical(probs=prob, dtype=tf.float32)
                    entropy = tf.math.reduce_mean(dist.entropy())
                    new_log_probs = dist.log_prob(action)

                    # PPO ratio
                    ratio = tf.math.exp(new_log_probs - old_log_probs)
                    surr1 = ratio * advantage
                    surr2 = tf.clip_by_value(ratio, 1.0 - self.clip_pram, 1.0 + self.clip_pram) * advantage

                    actor_loss = tf.math.negative(tf.math.reduce_mean(tf.math.minimum(surr1, surr2))) - 0.1 * entropy
                    critic_loss = 0.5 * tf.math.reduce_mean(kls.mean_squared_error(reward, value))

                    total_loss = actor_loss + critic_loss
            
                # single optimizer
                grads = tape.gradient(total_loss, self.actor_critic.trainable_variables)
                self.optimizer.apply_gradients(zip(grads, self.actor_critic.trainable_variables))
      
                total_actor_loss += actor_loss
                total_critic_loss += critic_loss
        return total_actor_loss, total_critic_loss

# %%
# https://arxiv.org/pdf/1506.02438.pdf
# Equation 16
def compute_gae(rewards, masks, values, gamma, LAMBDA):
    gae = 0
    returns = []
    for i in reversed(range(len(rewards))):
        delta = rewards[i] + gamma * values[i + 1] * masks[i] - values[i]
        gae = delta + gamma * LAMBDA * masks[i] * gae
        returns.append(gae + values[i])

    returns.reverse()
    return returns

# %% [markdown]
# ## Testing Environment

# %%
def test_reward(test_env, agent):
    total_reward = 0
    # Reset the environment
    test_env.reset_game()
    input_frames = [preprocess_screen(test_env.getScreenGrayscale())]

    while not test_env.game_over():

        state = frames_to_state(input_frames)
        state = tf.expand_dims(state, axis=0)
        prob, value = agent.actor_critic(state)

        action = np.argmax(prob[0].numpy())
        reward = test_env.act(test_env.getActionSet()[action])
        total_reward += reward

        input_frames.append(preprocess_screen(test_env.getScreenGrayscale()))

    return total_reward

# %% [markdown]
# ## Training

# %%
agent = Agent(hparas)
max_episode = hparas['max_episode']
test_per_n_episode = 10
force_save_per_n_episode = 1000
early_stop_reward = 10

start_s = 0
best_reward = -5.0

checkpoint = tf.train.Checkpoint(
    actor_critic = agent.actor_critic,
    optimizer = agent.optimizer,
)

# Load from old checkpoint
# checkpoint.restore('ckpt_dir/ckpt-?')

# %%
ep_reward = []
total_avgr = []
early_stop = False
avg_rewards_list = []

env.reset_game()

for s in range(0, max_episode):
    if early_stop == True:
        break

    rewards = []
    states = []
    actions = []
    log_probs = []
    masks = []
    values = []

    display_frames = [env.getScreenRGB()]
    input_frames = [preprocess_screen(env.getScreenGrayscale())]

    for step in range(hparas['num_steps']):

        state = frames_to_state(input_frames)
        state = tf.expand_dims(state, axis=0)
        prob, value = agent.actor_critic(state)

        dist = tfp.distributions.Categorical(probs=prob[0], dtype=tf.float32)
        action = dist.sample(1)
        log_prob = dist.log_prob(action)

        reward = env.act(env.getActionSet()[int(action.numpy())])

        done = env.game_over()

        states.append(state)
        actions.append(action)
        values.append(value[0])
        log_probs.append(log_prob)
        rewards.append(tf.convert_to_tensor(reward, dtype=tf.float32))
        masks.append(tf.convert_to_tensor(1-int(done), dtype=tf.float32))

        display_frames.append(env.getScreenRGB())
        input_frames.append(preprocess_screen(env.getScreenGrayscale()))

        if done:
            env.reset_game()
            input_frames = [preprocess_screen(env.getScreenGrayscale())]
  
    _, next_value = agent.actor_critic(state)
    values.append(next_value[0])

    returns = compute_gae(rewards, masks, values, hparas['gamma'], hparas['lambda'])

    returns = tf.concat(returns, axis=0)
    log_probs = tf.concat(log_probs, axis=0)
    values = tf.concat(values, axis=0)
    states = tf.concat(states, axis=0)
    actions = tf.concat(actions, axis=0)
    advantage = returns - values[:-1]

    a_loss, c_loss = agent.ppo_update(hparas['ppo_epochs'], hparas['mini_batch_size'], states, actions, log_probs, returns, advantage)
    print('[Episode %d]  Actor loss: %.5f, Critic loss: %.5f' % (s, a_loss, c_loss))

    if s % test_per_n_episode == 0:
        # test agent hparas['test_epochs'] times to get the average reward
        avg_reward = np.mean([test_reward(test_env, agent) for _ in range(hparas['test_epochs'])])
        print("Test average reward is %.1f, Current best average reward is %.1f\n" % (avg_reward, best_reward))
        avg_rewards_list.append(avg_reward)

        if avg_reward > best_reward:
            best_reward = avg_reward
            agent.actor_critic.save('./save/Actor/model_actor_{}_{}'.format(s, avg_reward), save_format="tf")
            checkpoint.save(file_prefix = './save/checkpoints/ckpt')

    if s % force_save_per_n_episode == 0:
        agent.actor_critic.save('./save/Actor/model_actor_{}_{}'.format(s, avg_reward), save_format="tf")
        checkpoint.save(file_prefix = './save/checkpoints/ckpt')
        clip = make_anim(display_frames, fps=60, true_image=True).rotate(-90)
        clip.write_videofile("movie_f/{}_demo-{}.webm".format('Lab15', s), fps=60)
        display(clip.ipython_display(fps=60, autoplay=1, loop=1, maxduration=120))

    if best_reward >= early_stop_reward:
        early_stop = True
# Out:
# [Episode 0]  Actor loss: 78.67571, Critic loss: 60.07767
# Test average reward is -5.0, Current best average reward is -5.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_0_-5.0\assets
# Moviepy - Building video movie_f/Lab15_demo-0.webm.
# Moviepy - Writing video movie_f/Lab15_demo-0.webm
# Moviepy - Done !
# Moviepy - video ready movie_f/Lab15_demo-0.webm
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video autoplay='1' loop='1'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# [Episode 1]  Actor loss: 48.18402, Critic loss: 35.33224
# [Episode 2]  Actor loss: 40.89743, Critic loss: 24.75761
# [Episode 3]  Actor loss: 22.85589, Critic loss: 13.12137
# [Episode 4]  Actor loss: 18.16325, Critic loss: 7.77806
# [Episode 5]  Actor loss: 20.16643, Critic loss: 6.71530
# [Episode 6]  Actor loss: 1.91814, Critic loss: 3.23884
# [Episode 7]  Actor loss: 4.25463, Critic loss: 4.61538
# [Episode 8]  Actor loss: -0.09294, Critic loss: 3.66436
# [Episode 9]  Actor loss: -10.12521, Critic loss: 2.54103
# [Episode 10]  Actor loss: -6.89476, Critic loss: 2.17800
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 11]  Actor loss: -9.71891, Critic loss: 2.66344
# [Episode 12]  Actor loss: 0.64489, Critic loss: 2.76453
# [Episode 13]  Actor loss: -3.38575, Critic loss: 2.18189
# [Episode 14]  Actor loss: -3.92528, Critic loss: 2.11146
# [Episode 15]  Actor loss: -3.46103, Critic loss: 2.14489
# [Episode 16]  Actor loss: -0.70099, Critic loss: 2.84826
# [Episode 17]  Actor loss: -2.73850, Critic loss: 1.93803
# [Episode 18]  Actor loss: -3.17376, Critic loss: 2.34337
# [Episode 19]  Actor loss: -6.32613, Critic loss: 2.91513
# [Episode 20]  Actor loss: -5.89590, Critic loss: 1.36799
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 21]  Actor loss: -3.20737, Critic loss: 2.00794
# [Episode 22]  Actor loss: -6.79613, Critic loss: 1.22890
# [Episode 23]  Actor loss: -9.12235, Critic loss: 0.85934
# [Episode 24]  Actor loss: -5.34760, Critic loss: 1.49685
# [Episode 25]  Actor loss: -1.22339, Critic loss: 1.85652
# [Episode 26]  Actor loss: -5.71618, Critic loss: 1.17048
# [Episode 27]  Actor loss: -6.06207, Critic loss: 1.20646
# [Episode 28]  Actor loss: -9.11459, Critic loss: 1.08039
# [Episode 29]  Actor loss: -4.78014, Critic loss: 1.73879
# [Episode 30]  Actor loss: -4.94819, Critic loss: 0.94787
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 31]  Actor loss: 1.21904, Critic loss: 1.44605
# [Episode 32]  Actor loss: -0.75330, Critic loss: 0.88860
# [Episode 33]  Actor loss: -4.81005, Critic loss: 0.60487
# [Episode 34]  Actor loss: -6.38263, Critic loss: 1.94340
# [Episode 35]  Actor loss: -10.77538, Critic loss: 1.52180
# [Episode 36]  Actor loss: -3.36169, Critic loss: 0.79188
# [Episode 37]  Actor loss: -5.81890, Critic loss: 0.83920
# [Episode 38]  Actor loss: -2.79707, Critic loss: 1.39956
# [Episode 39]  Actor loss: -5.60786, Critic loss: 0.84259
# [Episode 40]  Actor loss: -9.59598, Critic loss: 0.85688
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 41]  Actor loss: -3.51466, Critic loss: 0.93527
# [Episode 42]  Actor loss: -7.79885, Critic loss: 0.65143
# [Episode 43]  Actor loss: -8.87335, Critic loss: 1.61820
# [Episode 44]  Actor loss: 0.09713, Critic loss: 0.83600
# [Episode 45]  Actor loss: -13.87672, Critic loss: 2.48195
# [Episode 46]  Actor loss: -5.43300, Critic loss: 1.07254
# [Episode 47]  Actor loss: -2.57771, Critic loss: 0.51227
# [Episode 48]  Actor loss: -4.29816, Critic loss: 0.49103
# [Episode 49]  Actor loss: 0.36300, Critic loss: 0.81848
# [Episode 50]  Actor loss: -2.52292, Critic loss: 0.64137
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 51]  Actor loss: -1.66160, Critic loss: 0.63987
# [Episode 52]  Actor loss: 3.30580, Critic loss: 0.87420
# [Episode 53]  Actor loss: -6.91267, Critic loss: 0.32765
# [Episode 54]  Actor loss: -3.59932, Critic loss: 0.80775
# [Episode 55]  Actor loss: -2.74663, Critic loss: 1.05643
# [Episode 56]  Actor loss: -6.39457, Critic loss: 0.52441
# [Episode 57]  Actor loss: -11.25213, Critic loss: 1.40999
# [Episode 58]  Actor loss: -13.12712, Critic loss: 1.79889
# [Episode 59]  Actor loss: -3.78225, Critic loss: 1.32674
# [Episode 60]  Actor loss: -11.05977, Critic loss: 1.69691
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 61]  Actor loss: 1.68634, Critic loss: 1.08826
# [Episode 62]  Actor loss: -7.69961, Critic loss: 1.80183
# [Episode 63]  Actor loss: -1.10104, Critic loss: 1.12914
# [Episode 64]  Actor loss: -5.58003, Critic loss: 0.71709
# [Episode 65]  Actor loss: -12.26568, Critic loss: 1.54756
# [Episode 66]  Actor loss: -3.44381, Critic loss: 1.23439
# [Episode 67]  Actor loss: 0.43427, Critic loss: 0.60668
# [Episode 68]  Actor loss: -9.21721, Critic loss: 0.61391
# [Episode 69]  Actor loss: -5.37550, Critic loss: 0.92953
# [Episode 70]  Actor loss: 2.78081, Critic loss: 1.23052
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 71]  Actor loss: -7.47808, Critic loss: 0.58355
# [Episode 72]  Actor loss: -2.32964, Critic loss: 0.47534
# [Episode 73]  Actor loss: -2.17295, Critic loss: 0.84450
# [Episode 74]  Actor loss: -2.62944, Critic loss: 0.42927
# [Episode 75]  Actor loss: -4.43765, Critic loss: 0.33387
# [Episode 76]  Actor loss: -6.59401, Critic loss: 0.67079
# [Episode 77]  Actor loss: -4.73801, Critic loss: 0.59145
# [Episode 78]  Actor loss: -6.14853, Critic loss: 0.40425
# [Episode 79]  Actor loss: -4.45646, Critic loss: 0.61068
# [Episode 80]  Actor loss: -7.09227, Critic loss: 0.48621
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 81]  Actor loss: -4.06180, Critic loss: 0.56589
# [Episode 82]  Actor loss: -3.23821, Critic loss: 0.32746
# [Episode 83]  Actor loss: -5.39199, Critic loss: 0.57975
# [Episode 84]  Actor loss: -6.21489, Critic loss: 0.39228
# [Episode 85]  Actor loss: -2.75756, Critic loss: 0.70597
# [Episode 86]  Actor loss: -7.61813, Critic loss: 0.28650
# [Episode 87]  Actor loss: -4.82072, Critic loss: 0.36032
# [Episode 88]  Actor loss: -9.87196, Critic loss: 0.74072
# [Episode 89]  Actor loss: -5.36354, Critic loss: 0.84763
# [Episode 90]  Actor loss: -7.81384, Critic loss: 0.38504
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 91]  Actor loss: -5.99039, Critic loss: 1.39051
# [Episode 92]  Actor loss: -3.11658, Critic loss: 0.44861
# [Episode 93]  Actor loss: -5.28304, Critic loss: 0.48715
# [Episode 94]  Actor loss: -5.62814, Critic loss: 0.49875
# [Episode 95]  Actor loss: -2.67221, Critic loss: 0.58519
# [Episode 96]  Actor loss: -6.26634, Critic loss: 0.49023
# [Episode 97]  Actor loss: -4.99784, Critic loss: 0.35040
# [Episode 98]  Actor loss: -8.54515, Critic loss: 1.18816
# [Episode 99]  Actor loss: 5.33819, Critic loss: 0.47141
# [Episode 100]  Actor loss: 2.74039, Critic loss: 0.57709
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 101]  Actor loss: -6.80668, Critic loss: 0.35294
# [Episode 102]  Actor loss: -6.72012, Critic loss: 0.53110
# [Episode 103]  Actor loss: -8.70109, Critic loss: 0.36589
# [Episode 104]  Actor loss: -2.36787, Critic loss: 0.62648
# [Episode 105]  Actor loss: -5.63039, Critic loss: 0.99167
# [Episode 106]  Actor loss: -1.78173, Critic loss: 0.49351
# [Episode 107]  Actor loss: -3.54571, Critic loss: 0.64728
# [Episode 108]  Actor loss: -2.09061, Critic loss: 0.33027
# [Episode 109]  Actor loss: -3.77581, Critic loss: 0.42335
# [Episode 110]  Actor loss: -5.98552, Critic loss: 0.46942
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 111]  Actor loss: 0.12096, Critic loss: 0.80709
# [Episode 112]  Actor loss: -8.27077, Critic loss: 0.44628
# [Episode 113]  Actor loss: -1.65664, Critic loss: 0.46853
# [Episode 114]  Actor loss: -5.80069, Critic loss: 0.45293
# [Episode 115]  Actor loss: -5.66970, Critic loss: 0.48555
# [Episode 116]  Actor loss: -8.51087, Critic loss: 0.56004
# [Episode 117]  Actor loss: -4.03066, Critic loss: 0.55776
# [Episode 118]  Actor loss: -3.08207, Critic loss: 0.38988
# [Episode 119]  Actor loss: -2.25077, Critic loss: 0.52106
# [Episode 120]  Actor loss: -6.16987, Critic loss: 0.27646
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 121]  Actor loss: -3.70159, Critic loss: 1.24825
# [Episode 122]  Actor loss: -4.75930, Critic loss: 0.42890
# [Episode 123]  Actor loss: -4.50409, Critic loss: 0.52811
# [Episode 124]  Actor loss: -7.10265, Critic loss: 0.27080
# [Episode 125]  Actor loss: -1.43836, Critic loss: 0.61931
# [Episode 126]  Actor loss: -8.02242, Critic loss: 0.48233
# [Episode 127]  Actor loss: -4.60904, Critic loss: 0.46986
# [Episode 128]  Actor loss: -6.93157, Critic loss: 0.27977
# [Episode 129]  Actor loss: -5.88276, Critic loss: 0.44512
# [Episode 130]  Actor loss: -4.63131, Critic loss: 0.34294
# Test average reward is -5.0, Current best average reward is -5.0
#
# [Episode 131]  Actor loss: -5.82795, Critic loss: 0.40589
# [Episode 132]  Actor loss: -9.72570, Critic loss: 0.35746
# [Episode 133]  Actor loss: -6.13100, Critic loss: 0.59468
# [Episode 134]  Actor loss: -3.00975, Critic loss: 0.38119
# [Episode 135]  Actor loss: -5.36829, Critic loss: 0.35244
# [Episode 136]  Actor loss: -5.92576, Critic loss: 0.40694
# [Episode 137]  Actor loss: -4.18219, Critic loss: 0.31443
# [Episode 138]  Actor loss: -5.03850, Critic loss: 0.45025
# [Episode 139]  Actor loss: -4.28860, Critic loss: 0.44629
# [Episode 140]  Actor loss: -4.95734, Critic loss: 0.48304
# Test average reward is -4.0, Current best average reward is -5.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_140_-4.0\assets
# [Episode 141]  Actor loss: -4.07350, Critic loss: 0.45784
# [Episode 142]  Actor loss: -2.49891, Critic loss: 0.40143
# [Episode 143]  Actor loss: -2.76573, Critic loss: 0.49529
# [Episode 144]  Actor loss: -5.44534, Critic loss: 0.24553
# [Episode 145]  Actor loss: -5.46930, Critic loss: 0.39197
# [Episode 146]  Actor loss: -4.31756, Critic loss: 0.35746
# [Episode 147]  Actor loss: -3.98725, Critic loss: 0.47884
# [Episode 148]  Actor loss: -2.26198, Critic loss: 0.65953
# [Episode 149]  Actor loss: -6.75062, Critic loss: 0.38500
# [Episode 150]  Actor loss: -6.83808, Critic loss: 0.31991
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 151]  Actor loss: -2.23659, Critic loss: 0.48686
# [Episode 152]  Actor loss: -6.21537, Critic loss: 0.46836
# [Episode 153]  Actor loss: -2.51560, Critic loss: 0.55503
# [Episode 154]  Actor loss: -4.90242, Critic loss: 0.41243
# [Episode 155]  Actor loss: -5.47300, Critic loss: 0.31455
# [Episode 156]  Actor loss: -3.95688, Critic loss: 0.27869
# [Episode 157]  Actor loss: -6.61581, Critic loss: 0.21635
# [Episode 158]  Actor loss: -3.38006, Critic loss: 0.28838
# [Episode 159]  Actor loss: -7.36142, Critic loss: 0.22058
# [Episode 160]  Actor loss: -5.22638, Critic loss: 0.19097
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 161]  Actor loss: -0.64574, Critic loss: 0.26403
# [Episode 162]  Actor loss: -0.43011, Critic loss: 0.41373
# [Episode 163]  Actor loss: -6.30646, Critic loss: 0.30531
# [Episode 164]  Actor loss: -7.10420, Critic loss: 0.35327
# [Episode 165]  Actor loss: -8.39102, Critic loss: 0.83814
# [Episode 166]  Actor loss: -5.79842, Critic loss: 0.38726
# [Episode 167]  Actor loss: -10.20742, Critic loss: 0.78979
# [Episode 168]  Actor loss: -7.09002, Critic loss: 0.35616
# [Episode 169]  Actor loss: -4.41099, Critic loss: 0.28018
# [Episode 170]  Actor loss: -3.93077, Critic loss: 0.48046
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 171]  Actor loss: -7.09538, Critic loss: 0.34939
# [Episode 172]  Actor loss: -6.75099, Critic loss: 0.34141
# [Episode 173]  Actor loss: -2.19920, Critic loss: 0.69341
# [Episode 174]  Actor loss: -4.68652, Critic loss: 0.26947
# [Episode 175]  Actor loss: -4.28510, Critic loss: 0.29931
# [Episode 176]  Actor loss: -2.17209, Critic loss: 0.47346
# [Episode 177]  Actor loss: -6.89668, Critic loss: 0.49971
# [Episode 178]  Actor loss: -8.32643, Critic loss: 0.23866
# [Episode 179]  Actor loss: -4.05321, Critic loss: 0.31969
# [Episode 180]  Actor loss: -3.15065, Critic loss: 0.40990
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 181]  Actor loss: -5.38397, Critic loss: 0.35964
# [Episode 182]  Actor loss: -4.89547, Critic loss: 0.46619
# [Episode 183]  Actor loss: -1.68975, Critic loss: 0.44495
# [Episode 184]  Actor loss: -5.13409, Critic loss: 0.74650
# [Episode 185]  Actor loss: -3.25229, Critic loss: 0.51949
# [Episode 186]  Actor loss: -4.63676, Critic loss: 1.06055
# [Episode 187]  Actor loss: -4.72993, Critic loss: 0.35285
# [Episode 188]  Actor loss: -7.95569, Critic loss: 1.32345
# [Episode 189]  Actor loss: -1.09134, Critic loss: 0.42145
# [Episode 190]  Actor loss: -4.28316, Critic loss: 0.70778
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 191]  Actor loss: -6.29402, Critic loss: 0.78200
# [Episode 192]  Actor loss: -5.03019, Critic loss: 0.44490
# [Episode 193]  Actor loss: -3.42693, Critic loss: 0.55260
# [Episode 194]  Actor loss: -8.09161, Critic loss: 0.35438
# [Episode 195]  Actor loss: -3.51369, Critic loss: 0.27700
# [Episode 196]  Actor loss: -4.89763, Critic loss: 0.46454
# [Episode 197]  Actor loss: -7.89141, Critic loss: 0.30704
# [Episode 198]  Actor loss: -5.47404, Critic loss: 0.25295
# [Episode 199]  Actor loss: -3.95910, Critic loss: 0.48310
# [Episode 200]  Actor loss: -5.98953, Critic loss: 0.37694
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 201]  Actor loss: -7.03890, Critic loss: 0.44703
# [Episode 202]  Actor loss: -2.29286, Critic loss: 0.39935
# [Episode 203]  Actor loss: 2.41883, Critic loss: 0.47608
# [Episode 204]  Actor loss: -6.10305, Critic loss: 0.26588
# [Episode 205]  Actor loss: -3.90192, Critic loss: 0.36639
# [Episode 206]  Actor loss: -5.72248, Critic loss: 0.31850
# [Episode 207]  Actor loss: -2.42202, Critic loss: 0.74223
# [Episode 208]  Actor loss: -7.24396, Critic loss: 0.43286
# [Episode 209]  Actor loss: -4.46462, Critic loss: 0.30266
# [Episode 210]  Actor loss: -7.08275, Critic loss: 0.28262
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 211]  Actor loss: -4.92875, Critic loss: 0.56183
# [Episode 212]  Actor loss: -4.62176, Critic loss: 0.37563
# [Episode 213]  Actor loss: -4.47939, Critic loss: 0.42858
# [Episode 214]  Actor loss: -3.01232, Critic loss: 0.41536
# [Episode 215]  Actor loss: -5.75752, Critic loss: 0.31812
# [Episode 216]  Actor loss: -5.63628, Critic loss: 0.36603
# [Episode 217]  Actor loss: -3.99166, Critic loss: 0.29317
# [Episode 218]  Actor loss: -6.51679, Critic loss: 0.40043
# [Episode 219]  Actor loss: -0.78742, Critic loss: 0.46620
# [Episode 220]  Actor loss: -6.18738, Critic loss: 0.29748
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 221]  Actor loss: -3.05989, Critic loss: 0.34625
# [Episode 222]  Actor loss: -2.92069, Critic loss: 0.47223
# [Episode 223]  Actor loss: -5.34208, Critic loss: 0.61046
# [Episode 224]  Actor loss: -1.42392, Critic loss: 0.43502
# [Episode 225]  Actor loss: -4.33830, Critic loss: 0.24905
# [Episode 226]  Actor loss: -1.79124, Critic loss: 0.29538
# [Episode 227]  Actor loss: -2.68415, Critic loss: 0.23242
# [Episode 228]  Actor loss: -7.44559, Critic loss: 0.38632
# [Episode 229]  Actor loss: -6.07745, Critic loss: 0.31514
# [Episode 230]  Actor loss: -4.90112, Critic loss: 0.25316
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 231]  Actor loss: -7.02597, Critic loss: 0.28465
# [Episode 232]  Actor loss: -1.27638, Critic loss: 0.36858
# [Episode 233]  Actor loss: -4.77860, Critic loss: 0.75421
# [Episode 234]  Actor loss: -1.40865, Critic loss: 0.66779
# [Episode 235]  Actor loss: 0.10941, Critic loss: 0.53824
# [Episode 236]  Actor loss: -2.71112, Critic loss: 0.34994
# [Episode 237]  Actor loss: -9.99077, Critic loss: 0.41635
# [Episode 238]  Actor loss: -4.04247, Critic loss: 0.32820
# [Episode 239]  Actor loss: -8.38906, Critic loss: 0.57706
# [Episode 240]  Actor loss: -4.30765, Critic loss: 0.52584
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 241]  Actor loss: -2.09719, Critic loss: 0.33249
# [Episode 242]  Actor loss: -0.39477, Critic loss: 0.30537
# [Episode 243]  Actor loss: -4.48015, Critic loss: 0.34662
# [Episode 244]  Actor loss: -6.08115, Critic loss: 0.54784
# [Episode 245]  Actor loss: -5.24798, Critic loss: 0.63350
# [Episode 246]  Actor loss: -3.23175, Critic loss: 0.35493
# [Episode 247]  Actor loss: -9.56941, Critic loss: 0.65544
# [Episode 248]  Actor loss: -4.79957, Critic loss: 0.44906
# [Episode 249]  Actor loss: -5.53120, Critic loss: 0.80783
# [Episode 250]  Actor loss: -1.46751, Critic loss: 0.56270
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 251]  Actor loss: -8.22250, Critic loss: 0.60932
# [Episode 252]  Actor loss: -1.03912, Critic loss: 0.28539
# [Episode 253]  Actor loss: -10.99760, Critic loss: 1.06918
# [Episode 254]  Actor loss: -4.10508, Critic loss: 0.62510
# [Episode 255]  Actor loss: -3.71400, Critic loss: 0.49261
# [Episode 256]  Actor loss: -5.56499, Critic loss: 0.45993
# [Episode 257]  Actor loss: -2.90682, Critic loss: 0.58869
# [Episode 258]  Actor loss: -1.93860, Critic loss: 0.33711
# [Episode 259]  Actor loss: -4.99322, Critic loss: 0.45921
# [Episode 260]  Actor loss: -3.11502, Critic loss: 0.31820
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 261]  Actor loss: -11.64343, Critic loss: 0.55293
# [Episode 262]  Actor loss: -2.22914, Critic loss: 0.59083
# [Episode 263]  Actor loss: -3.76671, Critic loss: 0.49905
# [Episode 264]  Actor loss: -3.91083, Critic loss: 0.56271
# [Episode 265]  Actor loss: -5.10161, Critic loss: 0.50813
# [Episode 266]  Actor loss: -2.68573, Critic loss: 0.45311
# [Episode 267]  Actor loss: -8.58499, Critic loss: 0.63459
# [Episode 268]  Actor loss: -6.73526, Critic loss: 0.77718
# [Episode 269]  Actor loss: -3.08478, Critic loss: 0.75875
# [Episode 270]  Actor loss: -8.23303, Critic loss: 0.31618
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 271]  Actor loss: -4.51042, Critic loss: 0.38275
# [Episode 272]  Actor loss: -4.02900, Critic loss: 0.33779
# [Episode 273]  Actor loss: -2.77187, Critic loss: 0.39955
# [Episode 274]  Actor loss: -6.53842, Critic loss: 0.40801
# [Episode 275]  Actor loss: -5.35439, Critic loss: 0.30922
# [Episode 276]  Actor loss: -5.69598, Critic loss: 0.40806
# [Episode 277]  Actor loss: -3.78274, Critic loss: 0.20732
# [Episode 278]  Actor loss: -5.32164, Critic loss: 0.23377
# [Episode 279]  Actor loss: -5.20831, Critic loss: 0.55508
# [Episode 280]  Actor loss: -2.58472, Critic loss: 0.32654
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 281]  Actor loss: -4.71020, Critic loss: 0.42768
# [Episode 282]  Actor loss: -1.93594, Critic loss: 0.38757
# [Episode 283]  Actor loss: -0.53021, Critic loss: 0.36817
# [Episode 284]  Actor loss: -3.08602, Critic loss: 0.37816
# [Episode 285]  Actor loss: -2.43199, Critic loss: 0.36860
# [Episode 286]  Actor loss: -6.69907, Critic loss: 0.30932
# [Episode 287]  Actor loss: -3.43270, Critic loss: 0.25277
# [Episode 288]  Actor loss: -3.08719, Critic loss: 0.21835
# [Episode 289]  Actor loss: -4.02316, Critic loss: 0.45245
# [Episode 290]  Actor loss: -3.17637, Critic loss: 0.41279
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 291]  Actor loss: -4.00444, Critic loss: 0.47814
# [Episode 292]  Actor loss: -7.19504, Critic loss: 0.34997
# [Episode 293]  Actor loss: -6.86167, Critic loss: 0.66852
# [Episode 294]  Actor loss: -7.23301, Critic loss: 0.82324
# [Episode 295]  Actor loss: -4.86368, Critic loss: 0.36293
# [Episode 296]  Actor loss: -2.48431, Critic loss: 0.30317
# [Episode 297]  Actor loss: -4.25900, Critic loss: 0.27023
# [Episode 298]  Actor loss: -1.82764, Critic loss: 0.47244
# [Episode 299]  Actor loss: -6.62752, Critic loss: 0.36329
# [Episode 300]  Actor loss: -2.91312, Critic loss: 0.24615
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 301]  Actor loss: -1.65108, Critic loss: 0.27829
# [Episode 302]  Actor loss: -4.06566, Critic loss: 0.26384
# [Episode 303]  Actor loss: -5.25219, Critic loss: 0.36421
# [Episode 304]  Actor loss: -5.06210, Critic loss: 0.34999
# [Episode 305]  Actor loss: -4.09398, Critic loss: 0.24738
# [Episode 306]  Actor loss: -6.91634, Critic loss: 0.46569
# [Episode 307]  Actor loss: -7.56917, Critic loss: 0.40068
# [Episode 308]  Actor loss: -5.93150, Critic loss: 0.35569
# [Episode 309]  Actor loss: -6.94076, Critic loss: 0.27923
# [Episode 310]  Actor loss: -3.92463, Critic loss: 0.24157
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 311]  Actor loss: -5.79738, Critic loss: 0.39018
# [Episode 312]  Actor loss: -9.87980, Critic loss: 0.62517
# [Episode 313]  Actor loss: -2.06473, Critic loss: 0.36866
# [Episode 314]  Actor loss: -3.95178, Critic loss: 0.27245
# [Episode 315]  Actor loss: -7.30663, Critic loss: 0.26236
# [Episode 316]  Actor loss: -6.52312, Critic loss: 0.50314
# [Episode 317]  Actor loss: -2.72540, Critic loss: 0.58738
# [Episode 318]  Actor loss: -5.69903, Critic loss: 0.39837
# [Episode 319]  Actor loss: -5.66855, Critic loss: 0.30956
# [Episode 320]  Actor loss: -3.71767, Critic loss: 0.54816
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 321]  Actor loss: -2.75227, Critic loss: 0.36235
# [Episode 322]  Actor loss: -2.91489, Critic loss: 0.33189
# [Episode 323]  Actor loss: -6.09474, Critic loss: 0.21830
# [Episode 324]  Actor loss: -12.17745, Critic loss: 1.38514
# [Episode 325]  Actor loss: -0.75661, Critic loss: 0.65604
# [Episode 326]  Actor loss: -5.30871, Critic loss: 0.52994
# [Episode 327]  Actor loss: -3.59852, Critic loss: 0.38634
# [Episode 328]  Actor loss: -6.07096, Critic loss: 0.29723
# [Episode 329]  Actor loss: -4.61058, Critic loss: 0.28086
# [Episode 330]  Actor loss: -5.92566, Critic loss: 0.35980
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 331]  Actor loss: -8.01182, Critic loss: 1.12811
# [Episode 332]  Actor loss: -5.03306, Critic loss: 0.43497
# [Episode 333]  Actor loss: -0.04518, Critic loss: 0.45670
# [Episode 334]  Actor loss: -5.69948, Critic loss: 0.44396
# [Episode 335]  Actor loss: -5.90770, Critic loss: 0.61184
# [Episode 336]  Actor loss: -2.36341, Critic loss: 0.63632
# [Episode 337]  Actor loss: -7.19750, Critic loss: 0.70803
# [Episode 338]  Actor loss: -6.93855, Critic loss: 0.99528
# [Episode 339]  Actor loss: -8.35961, Critic loss: 0.86795
# [Episode 340]  Actor loss: 1.15536, Critic loss: 0.76719
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 341]  Actor loss: -2.78800, Critic loss: 0.39131
# [Episode 342]  Actor loss: -1.67824, Critic loss: 0.40306
# [Episode 343]  Actor loss: -0.10230, Critic loss: 0.64719
# [Episode 344]  Actor loss: -4.49633, Critic loss: 0.46622
# [Episode 345]  Actor loss: -0.88747, Critic loss: 0.51479
# [Episode 346]  Actor loss: -2.24596, Critic loss: 0.46882
# [Episode 347]  Actor loss: -2.50516, Critic loss: 0.50955
# [Episode 348]  Actor loss: -3.66643, Critic loss: 0.33473
# [Episode 349]  Actor loss: -6.58299, Critic loss: 0.39003
# [Episode 350]  Actor loss: -8.22427, Critic loss: 0.75457
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 351]  Actor loss: -1.95086, Critic loss: 0.73127
# [Episode 352]  Actor loss: -5.92688, Critic loss: 0.33219
# [Episode 353]  Actor loss: -9.55201, Critic loss: 0.30750
# [Episode 354]  Actor loss: -4.15467, Critic loss: 0.30006
# [Episode 355]  Actor loss: -4.89426, Critic loss: 0.24910
# [Episode 356]  Actor loss: -3.61291, Critic loss: 0.26296
# [Episode 357]  Actor loss: -1.77782, Critic loss: 0.60760
# [Episode 358]  Actor loss: -2.71849, Critic loss: 0.35500
# [Episode 359]  Actor loss: -5.51745, Critic loss: 0.29458
# [Episode 360]  Actor loss: -6.18074, Critic loss: 0.34421
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 361]  Actor loss: -5.78731, Critic loss: 0.57290
# [Episode 362]  Actor loss: -3.62948, Critic loss: 0.32723
# [Episode 363]  Actor loss: -5.12477, Critic loss: 0.29887
# [Episode 364]  Actor loss: -3.03109, Critic loss: 0.41774
# [Episode 365]  Actor loss: -3.61261, Critic loss: 0.28886
# [Episode 366]  Actor loss: -6.45658, Critic loss: 0.32787
# [Episode 367]  Actor loss: -5.25353, Critic loss: 0.44496
# [Episode 368]  Actor loss: -4.64264, Critic loss: 0.30324
# [Episode 369]  Actor loss: -6.67925, Critic loss: 0.34834
# [Episode 370]  Actor loss: -7.71040, Critic loss: 0.28550
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 371]  Actor loss: -1.70507, Critic loss: 0.48915
# [Episode 372]  Actor loss: -2.64183, Critic loss: 0.41142
# [Episode 373]  Actor loss: -4.52367, Critic loss: 0.55312
# [Episode 374]  Actor loss: -8.31330, Critic loss: 0.59847
# [Episode 375]  Actor loss: -3.40656, Critic loss: 0.45698
# [Episode 376]  Actor loss: -2.08953, Critic loss: 0.43722
# [Episode 377]  Actor loss: -6.22479, Critic loss: 0.69537
# [Episode 378]  Actor loss: -2.64026, Critic loss: 0.28138
# [Episode 379]  Actor loss: -6.29176, Critic loss: 0.26202
# [Episode 380]  Actor loss: -3.04902, Critic loss: 0.30581
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 381]  Actor loss: -6.57690, Critic loss: 0.38950
# [Episode 382]  Actor loss: -4.15885, Critic loss: 0.33412
# [Episode 383]  Actor loss: -7.36954, Critic loss: 0.41851
# [Episode 384]  Actor loss: -5.93408, Critic loss: 0.42781
# [Episode 385]  Actor loss: -3.26532, Critic loss: 0.24868
# [Episode 386]  Actor loss: -6.98454, Critic loss: 0.55341
# [Episode 387]  Actor loss: -4.36354, Critic loss: 0.84257
# [Episode 388]  Actor loss: -5.30963, Critic loss: 0.62201
# [Episode 389]  Actor loss: -1.06744, Critic loss: 0.34818
# [Episode 390]  Actor loss: -5.40862, Critic loss: 0.32145
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 391]  Actor loss: -4.44768, Critic loss: 0.54979
# [Episode 392]  Actor loss: -5.92367, Critic loss: 0.25227
# [Episode 393]  Actor loss: -5.36415, Critic loss: 0.61145
# [Episode 394]  Actor loss: -5.22734, Critic loss: 0.53729
# [Episode 395]  Actor loss: -2.91391, Critic loss: 0.59330
# [Episode 396]  Actor loss: -5.18104, Critic loss: 0.37449
# [Episode 397]  Actor loss: -2.85996, Critic loss: 0.43876
# [Episode 398]  Actor loss: -3.23359, Critic loss: 0.29215
# [Episode 399]  Actor loss: -2.20714, Critic loss: 0.37544
# [Episode 400]  Actor loss: -6.58374, Critic loss: 0.41429
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 401]  Actor loss: -6.86013, Critic loss: 0.32055
# [Episode 402]  Actor loss: -5.05321, Critic loss: 0.27083
# [Episode 403]  Actor loss: -8.17787, Critic loss: 0.29653
# [Episode 404]  Actor loss: -5.98060, Critic loss: 0.40120
# [Episode 405]  Actor loss: -4.24591, Critic loss: 0.27997
# [Episode 406]  Actor loss: -6.22763, Critic loss: 0.22148
# [Episode 407]  Actor loss: -4.07341, Critic loss: 0.22757
# [Episode 408]  Actor loss: -6.45865, Critic loss: 0.31858
# [Episode 409]  Actor loss: -4.37225, Critic loss: 0.36928
# [Episode 410]  Actor loss: -2.53697, Critic loss: 0.62469
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 411]  Actor loss: -4.66003, Critic loss: 0.61332
# [Episode 412]  Actor loss: -5.65180, Critic loss: 0.28866
# [Episode 413]  Actor loss: -0.33828, Critic loss: 0.48352
# [Episode 414]  Actor loss: -11.34904, Critic loss: 0.41392
# [Episode 415]  Actor loss: -6.88491, Critic loss: 0.32649
# [Episode 416]  Actor loss: -9.68210, Critic loss: 0.79727
# [Episode 417]  Actor loss: -2.84377, Critic loss: 0.62140
# [Episode 418]  Actor loss: -5.66727, Critic loss: 0.66656
# [Episode 419]  Actor loss: -2.90720, Critic loss: 0.51413
# [Episode 420]  Actor loss: -5.94356, Critic loss: 0.36598
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 421]  Actor loss: -4.41043, Critic loss: 0.50909
# [Episode 422]  Actor loss: -5.05970, Critic loss: 0.34305
# [Episode 423]  Actor loss: -2.88731, Critic loss: 0.30598
# [Episode 424]  Actor loss: -7.42725, Critic loss: 0.32930
# [Episode 425]  Actor loss: -3.71351, Critic loss: 0.28300
# [Episode 426]  Actor loss: -5.63271, Critic loss: 0.32539
# [Episode 427]  Actor loss: -3.94984, Critic loss: 0.29154
# [Episode 428]  Actor loss: -4.30805, Critic loss: 0.32443
# [Episode 429]  Actor loss: -3.81124, Critic loss: 0.35433
# [Episode 430]  Actor loss: -8.57571, Critic loss: 0.86202
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 431]  Actor loss: -3.27178, Critic loss: 0.26696
# [Episode 432]  Actor loss: -8.90951, Critic loss: 0.63062
# [Episode 433]  Actor loss: -5.79531, Critic loss: 0.33754
# [Episode 434]  Actor loss: -4.21489, Critic loss: 0.66303
# [Episode 435]  Actor loss: -6.92852, Critic loss: 0.47073
# [Episode 436]  Actor loss: -2.60506, Critic loss: 0.64614
# [Episode 437]  Actor loss: -4.43022, Critic loss: 0.32273
# [Episode 438]  Actor loss: -3.48116, Critic loss: 0.68065
# [Episode 439]  Actor loss: -7.41605, Critic loss: 0.26200
# [Episode 440]  Actor loss: -6.31687, Critic loss: 0.68288
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 441]  Actor loss: -4.35906, Critic loss: 0.67493
# [Episode 442]  Actor loss: -0.22830, Critic loss: 0.56556
# [Episode 443]  Actor loss: -12.70437, Critic loss: 1.39956
# [Episode 444]  Actor loss: -6.26053, Critic loss: 1.02143
# [Episode 445]  Actor loss: -12.81496, Critic loss: 1.06068
# [Episode 446]  Actor loss: -4.81577, Critic loss: 3.02759
# [Episode 447]  Actor loss: -4.86140, Critic loss: 0.72634
# [Episode 448]  Actor loss: 1.97544, Critic loss: 0.77151
# [Episode 449]  Actor loss: -1.70827, Critic loss: 0.39611
# [Episode 450]  Actor loss: -1.58797, Critic loss: 0.44644
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 451]  Actor loss: -2.27152, Critic loss: 0.59038
# [Episode 452]  Actor loss: -6.14400, Critic loss: 0.52052
# [Episode 453]  Actor loss: -6.70499, Critic loss: 0.35751
# [Episode 454]  Actor loss: -1.55669, Critic loss: 0.37782
# [Episode 455]  Actor loss: -2.82491, Critic loss: 0.49095
# [Episode 456]  Actor loss: -6.05753, Critic loss: 0.20325
# [Episode 457]  Actor loss: -4.69118, Critic loss: 0.39903
# [Episode 458]  Actor loss: -2.89624, Critic loss: 0.38338
# [Episode 459]  Actor loss: -1.73422, Critic loss: 0.36175
# [Episode 460]  Actor loss: -3.06321, Critic loss: 0.27316
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 461]  Actor loss: -5.19145, Critic loss: 0.26487
# [Episode 462]  Actor loss: -7.78218, Critic loss: 0.18042
# [Episode 463]  Actor loss: -3.24438, Critic loss: 0.44604
# [Episode 464]  Actor loss: -7.44677, Critic loss: 1.02613
# [Episode 465]  Actor loss: -10.28573, Critic loss: 1.50168
# [Episode 466]  Actor loss: -5.68417, Critic loss: 0.44002
# [Episode 467]  Actor loss: -2.67605, Critic loss: 0.37926
# [Episode 468]  Actor loss: -7.06888, Critic loss: 0.50425
# [Episode 469]  Actor loss: -2.32003, Critic loss: 0.72700
# [Episode 470]  Actor loss: -6.10365, Critic loss: 0.45728
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 471]  Actor loss: -3.34185, Critic loss: 0.56540
# [Episode 472]  Actor loss: -3.76565, Critic loss: 0.29219
# [Episode 473]  Actor loss: -7.86255, Critic loss: 1.06752
# [Episode 474]  Actor loss: -3.02546, Critic loss: 0.80844
# [Episode 475]  Actor loss: -3.09590, Critic loss: 0.49695
# [Episode 476]  Actor loss: -1.05056, Critic loss: 0.41680
# [Episode 477]  Actor loss: -3.30164, Critic loss: 0.67581
# [Episode 478]  Actor loss: -2.30625, Critic loss: 0.46440
# [Episode 479]  Actor loss: -3.22861, Critic loss: 0.37953
# [Episode 480]  Actor loss: -5.22468, Critic loss: 0.57643
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 481]  Actor loss: -2.18933, Critic loss: 0.47126
# [Episode 482]  Actor loss: -0.94286, Critic loss: 0.34233
# [Episode 483]  Actor loss: -6.64504, Critic loss: 0.77171
# [Episode 484]  Actor loss: -1.69608, Critic loss: 0.50031
# [Episode 485]  Actor loss: -4.38459, Critic loss: 0.38804
# [Episode 486]  Actor loss: -5.83238, Critic loss: 0.82278
# [Episode 487]  Actor loss: -5.98028, Critic loss: 0.46402
# [Episode 488]  Actor loss: -4.76405, Critic loss: 1.10244
# [Episode 489]  Actor loss: -2.30774, Critic loss: 0.30070
# [Episode 490]  Actor loss: -3.38398, Critic loss: 0.22529
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 491]  Actor loss: -0.69372, Critic loss: 0.29188
# [Episode 492]  Actor loss: -13.23303, Critic loss: 1.53533
# [Episode 493]  Actor loss: -3.06928, Critic loss: 0.66042
# [Episode 494]  Actor loss: -3.36164, Critic loss: 0.65658
# [Episode 495]  Actor loss: -5.68351, Critic loss: 1.65824
# [Episode 496]  Actor loss: -1.89543, Critic loss: 0.92309
# [Episode 497]  Actor loss: -2.28932, Critic loss: 0.34009
# [Episode 498]  Actor loss: -5.02356, Critic loss: 0.80627
# [Episode 499]  Actor loss: -4.72875, Critic loss: 0.47040
# [Episode 500]  Actor loss: -4.60979, Critic loss: 0.75410
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 501]  Actor loss: -2.65184, Critic loss: 0.81982
# [Episode 502]  Actor loss: -2.42842, Critic loss: 0.66853
# [Episode 503]  Actor loss: -8.84789, Critic loss: 0.66645
# [Episode 504]  Actor loss: -7.70579, Critic loss: 1.15648
# [Episode 505]  Actor loss: -4.99885, Critic loss: 0.39508
# [Episode 506]  Actor loss: -3.94171, Critic loss: 0.85989
# [Episode 507]  Actor loss: -2.55027, Critic loss: 0.25443
# [Episode 508]  Actor loss: -1.57371, Critic loss: 1.45217
# [Episode 509]  Actor loss: -4.98903, Critic loss: 0.58280
# [Episode 510]  Actor loss: -3.79868, Critic loss: 0.75360
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 511]  Actor loss: -4.72329, Critic loss: 0.86642
# [Episode 512]  Actor loss: -5.13943, Critic loss: 0.55391
# [Episode 513]  Actor loss: 1.52396, Critic loss: 0.78461
# [Episode 514]  Actor loss: -1.30930, Critic loss: 0.49591
# [Episode 515]  Actor loss: -4.34282, Critic loss: 0.22349
# [Episode 516]  Actor loss: -4.87300, Critic loss: 0.27540
# [Episode 517]  Actor loss: -8.33378, Critic loss: 0.63388
# [Episode 518]  Actor loss: -8.66387, Critic loss: 1.13055
# [Episode 519]  Actor loss: -8.27037, Critic loss: 0.43075
# [Episode 520]  Actor loss: -3.68025, Critic loss: 0.39900
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 521]  Actor loss: -8.68072, Critic loss: 0.59444
# [Episode 522]  Actor loss: -6.12446, Critic loss: 1.06242
# [Episode 523]  Actor loss: -9.57810, Critic loss: 0.28320
# [Episode 524]  Actor loss: -4.68486, Critic loss: 0.65443
# [Episode 525]  Actor loss: -5.07702, Critic loss: 0.38157
# [Episode 526]  Actor loss: -1.74636, Critic loss: 0.37661
# [Episode 527]  Actor loss: -4.96825, Critic loss: 0.31444
# [Episode 528]  Actor loss: -4.07572, Critic loss: 0.22483
# [Episode 529]  Actor loss: -10.50010, Critic loss: 0.83273
# [Episode 530]  Actor loss: -6.05877, Critic loss: 0.51571
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 531]  Actor loss: -6.28117, Critic loss: 0.75325
# [Episode 532]  Actor loss: -11.14859, Critic loss: 0.78395
# [Episode 533]  Actor loss: -7.00739, Critic loss: 0.86173
# [Episode 534]  Actor loss: -10.62273, Critic loss: 1.64004
# [Episode 535]  Actor loss: -0.99783, Critic loss: 0.93084
# [Episode 536]  Actor loss: -2.33495, Critic loss: 1.23296
# [Episode 537]  Actor loss: -5.10450, Critic loss: 0.79653
# [Episode 538]  Actor loss: -3.66781, Critic loss: 0.36606
# [Episode 539]  Actor loss: -5.21955, Critic loss: 1.13402
# [Episode 540]  Actor loss: -1.79220, Critic loss: 0.58700
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 541]  Actor loss: -4.70608, Critic loss: 0.86868
# [Episode 542]  Actor loss: -5.93472, Critic loss: 1.00897
# [Episode 543]  Actor loss: -3.54589, Critic loss: 0.26566
# [Episode 544]  Actor loss: -7.10346, Critic loss: 0.54476
# [Episode 545]  Actor loss: -1.23287, Critic loss: 0.41397
# [Episode 546]  Actor loss: -8.50071, Critic loss: 0.77220
# [Episode 547]  Actor loss: -5.82188, Critic loss: 0.76144
# [Episode 548]  Actor loss: -4.32342, Critic loss: 0.66390
# [Episode 549]  Actor loss: -0.14401, Critic loss: 0.57476
# [Episode 550]  Actor loss: -0.24228, Critic loss: 1.11856
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 551]  Actor loss: -7.51488, Critic loss: 0.81050
# [Episode 552]  Actor loss: -3.88564, Critic loss: 0.47694
# [Episode 553]  Actor loss: -3.19859, Critic loss: 0.67054
# [Episode 554]  Actor loss: -1.44541, Critic loss: 1.42408
# [Episode 555]  Actor loss: 2.10973, Critic loss: 0.66432
# [Episode 556]  Actor loss: -2.54982, Critic loss: 0.38762
# [Episode 557]  Actor loss: -9.77118, Critic loss: 0.44822
# [Episode 558]  Actor loss: -2.85923, Critic loss: 0.17068
# [Episode 559]  Actor loss: -8.72791, Critic loss: 0.38630
# [Episode 560]  Actor loss: -0.09687, Critic loss: 0.27024
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 561]  Actor loss: -1.42654, Critic loss: 0.46084
# [Episode 562]  Actor loss: -4.83462, Critic loss: 0.18236
# [Episode 563]  Actor loss: -10.46429, Critic loss: 0.89728
# [Episode 564]  Actor loss: -5.43456, Critic loss: 0.64900
# [Episode 565]  Actor loss: -0.00597, Critic loss: 0.38465
# [Episode 566]  Actor loss: -4.74309, Critic loss: 0.92769
# [Episode 567]  Actor loss: -14.09893, Critic loss: 1.50023
# [Episode 568]  Actor loss: -5.62549, Critic loss: 0.95499
# [Episode 569]  Actor loss: -5.64558, Critic loss: 0.64270
# [Episode 570]  Actor loss: -0.91763, Critic loss: 0.44986
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 571]  Actor loss: -10.96948, Critic loss: 0.76435
# [Episode 572]  Actor loss: -7.55298, Critic loss: 0.75125
# [Episode 573]  Actor loss: -8.13668, Critic loss: 1.16844
# [Episode 574]  Actor loss: 0.87366, Critic loss: 0.65897
# [Episode 575]  Actor loss: -6.19495, Critic loss: 0.81410
# [Episode 576]  Actor loss: -3.55814, Critic loss: 1.68882
# [Episode 577]  Actor loss: -5.60611, Critic loss: 0.91792
# [Episode 578]  Actor loss: -3.10156, Critic loss: 0.42852
# [Episode 579]  Actor loss: -3.24468, Critic loss: 0.26137
# [Episode 580]  Actor loss: -2.68219, Critic loss: 0.40071
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 581]  Actor loss: -5.13494, Critic loss: 0.28499
# [Episode 582]  Actor loss: -4.17366, Critic loss: 0.78073
# [Episode 583]  Actor loss: -1.95417, Critic loss: 0.62630
# [Episode 584]  Actor loss: -5.96401, Critic loss: 0.48152
# [Episode 585]  Actor loss: -6.79059, Critic loss: 0.32661
# [Episode 586]  Actor loss: -7.20659, Critic loss: 0.40293
# [Episode 587]  Actor loss: -1.11177, Critic loss: 0.25932
# [Episode 588]  Actor loss: -0.99943, Critic loss: 0.36877
# [Episode 589]  Actor loss: -2.61643, Critic loss: 0.23154
# [Episode 590]  Actor loss: -2.76449, Critic loss: 0.37210
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 591]  Actor loss: -5.12534, Critic loss: 0.47156
# [Episode 592]  Actor loss: -4.54987, Critic loss: 0.19548
# [Episode 593]  Actor loss: -11.40799, Critic loss: 1.29144
# [Episode 594]  Actor loss: -4.68520, Critic loss: 0.33974
# [Episode 595]  Actor loss: -3.83560, Critic loss: 0.49378
# [Episode 596]  Actor loss: -8.26884, Critic loss: 0.69191
# [Episode 597]  Actor loss: -6.47428, Critic loss: 0.68564
# [Episode 598]  Actor loss: -4.74023, Critic loss: 0.35749
# [Episode 599]  Actor loss: -7.43212, Critic loss: 0.27002
# [Episode 600]  Actor loss: -12.60069, Critic loss: 0.95385
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 601]  Actor loss: -5.85698, Critic loss: 0.29432
# [Episode 602]  Actor loss: -2.41623, Critic loss: 0.35399
# [Episode 603]  Actor loss: -6.32376, Critic loss: 0.53355
# [Episode 604]  Actor loss: -3.68484, Critic loss: 1.14405
# [Episode 605]  Actor loss: -6.50384, Critic loss: 0.28900
# [Episode 606]  Actor loss: -6.03246, Critic loss: 0.21222
# [Episode 607]  Actor loss: -7.40782, Critic loss: 1.36949
# [Episode 608]  Actor loss: -4.97951, Critic loss: 1.40962
# [Episode 609]  Actor loss: -8.17962, Critic loss: 0.92697
# [Episode 610]  Actor loss: -3.53245, Critic loss: 1.17104
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 611]  Actor loss: 1.21556, Critic loss: 0.88204
# [Episode 612]  Actor loss: -1.61050, Critic loss: 0.37565
# [Episode 613]  Actor loss: -4.86311, Critic loss: 0.71066
# [Episode 614]  Actor loss: -2.57012, Critic loss: 0.66388
# [Episode 615]  Actor loss: -3.77090, Critic loss: 0.11395
# [Episode 616]  Actor loss: -4.67411, Critic loss: 0.39422
# [Episode 617]  Actor loss: -2.08179, Critic loss: 0.39969
# [Episode 618]  Actor loss: -2.00251, Critic loss: 0.20539
# [Episode 619]  Actor loss: -6.29402, Critic loss: 0.51275
# [Episode 620]  Actor loss: -10.72795, Critic loss: 1.24130
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 621]  Actor loss: -6.22341, Critic loss: 0.88921
# [Episode 622]  Actor loss: -9.16619, Critic loss: 0.82985
# [Episode 623]  Actor loss: -2.66274, Critic loss: 0.34769
# [Episode 624]  Actor loss: -1.11746, Critic loss: 0.30057
# [Episode 625]  Actor loss: -2.34059, Critic loss: 0.49408
# [Episode 626]  Actor loss: -6.21009, Critic loss: 0.12338
# [Episode 627]  Actor loss: -13.08291, Critic loss: 0.83842
# [Episode 628]  Actor loss: -3.28242, Critic loss: 0.63559
# [Episode 629]  Actor loss: -6.96932, Critic loss: 0.93958
# [Episode 630]  Actor loss: -3.49968, Critic loss: 0.39890
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 631]  Actor loss: -6.60383, Critic loss: 0.54880
# [Episode 632]  Actor loss: -5.07642, Critic loss: 0.27998
# [Episode 633]  Actor loss: -4.54885, Critic loss: 0.57012
# [Episode 634]  Actor loss: -4.21730, Critic loss: 0.37940
# [Episode 635]  Actor loss: -19.53237, Critic loss: 2.17037
# [Episode 636]  Actor loss: -5.17009, Critic loss: 1.69153
# [Episode 637]  Actor loss: -1.55611, Critic loss: 0.61012
# [Episode 638]  Actor loss: -4.71196, Critic loss: 0.55244
# [Episode 639]  Actor loss: -10.89558, Critic loss: 1.79500
# [Episode 640]  Actor loss: -7.73294, Critic loss: 1.51719
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 641]  Actor loss: -1.04402, Critic loss: 0.89001
# [Episode 642]  Actor loss: -4.32307, Critic loss: 1.12565
# [Episode 643]  Actor loss: -7.00779, Critic loss: 0.83272
# [Episode 644]  Actor loss: -4.35430, Critic loss: 1.04949
# [Episode 645]  Actor loss: -5.51739, Critic loss: 0.64177
# [Episode 646]  Actor loss: -8.38239, Critic loss: 1.24269
# [Episode 647]  Actor loss: 0.51307, Critic loss: 1.50394
# [Episode 648]  Actor loss: -5.04239, Critic loss: 0.29504
# [Episode 649]  Actor loss: -8.23489, Critic loss: 0.90885
# [Episode 650]  Actor loss: -2.26195, Critic loss: 1.00650
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 651]  Actor loss: -1.01151, Critic loss: 0.68385
# [Episode 652]  Actor loss: -14.00250, Critic loss: 2.42509
# [Episode 653]  Actor loss: 0.21691, Critic loss: 1.27041
# [Episode 654]  Actor loss: -4.26922, Critic loss: 0.78432
# [Episode 655]  Actor loss: -12.16010, Critic loss: 1.42876
# [Episode 656]  Actor loss: -8.54752, Critic loss: 0.85942
# [Episode 657]  Actor loss: -8.26379, Critic loss: 0.95749
# [Episode 658]  Actor loss: -1.06239, Critic loss: 0.37214
# [Episode 659]  Actor loss: -0.31217, Critic loss: 0.70497
# [Episode 660]  Actor loss: -2.05056, Critic loss: 0.27584
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 661]  Actor loss: -6.69906, Critic loss: 1.05029
# [Episode 662]  Actor loss: -6.36162, Critic loss: 0.48100
# [Episode 663]  Actor loss: -5.34593, Critic loss: 0.58664
# [Episode 664]  Actor loss: -5.48765, Critic loss: 0.86147
# [Episode 665]  Actor loss: -8.76215, Critic loss: 0.80870
# [Episode 666]  Actor loss: -4.64883, Critic loss: 1.28090
# [Episode 667]  Actor loss: -5.13363, Critic loss: 0.67831
# [Episode 668]  Actor loss: -17.13526, Critic loss: 1.87181
# [Episode 669]  Actor loss: -3.78873, Critic loss: 1.52479
# [Episode 670]  Actor loss: -3.18880, Critic loss: 1.36898
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 671]  Actor loss: -0.18128, Critic loss: 1.57070
# [Episode 672]  Actor loss: 2.34528, Critic loss: 0.62235
# [Episode 673]  Actor loss: -0.07386, Critic loss: 0.99953
# [Episode 674]  Actor loss: -2.74423, Critic loss: 0.37248
# [Episode 675]  Actor loss: -0.70691, Critic loss: 0.39034
# [Episode 676]  Actor loss: -9.10742, Critic loss: 0.55088
# [Episode 677]  Actor loss: -4.95183, Critic loss: 0.64565
# [Episode 678]  Actor loss: -12.21570, Critic loss: 1.55111
# [Episode 679]  Actor loss: -4.49022, Critic loss: 1.26525
# [Episode 680]  Actor loss: -7.22764, Critic loss: 0.61803
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 681]  Actor loss: -6.33654, Critic loss: 0.86060
# [Episode 682]  Actor loss: 3.13303, Critic loss: 1.27136
# [Episode 683]  Actor loss: -2.86221, Critic loss: 1.20905
# [Episode 684]  Actor loss: -26.46862, Critic loss: 2.64245
# [Episode 685]  Actor loss: -11.62945, Critic loss: 1.32766
# [Episode 686]  Actor loss: 0.02150, Critic loss: 1.19282
# [Episode 687]  Actor loss: 0.29443, Critic loss: 1.84237
# [Episode 688]  Actor loss: -5.58416, Critic loss: 0.85438
# [Episode 689]  Actor loss: -2.09587, Critic loss: 0.26777
# [Episode 690]  Actor loss: -4.14747, Critic loss: 0.35184
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 691]  Actor loss: -12.70364, Critic loss: 0.96977
# [Episode 692]  Actor loss: 0.59311, Critic loss: 0.43115
# [Episode 693]  Actor loss: -3.56847, Critic loss: 0.52550
# [Episode 694]  Actor loss: 1.21280, Critic loss: 0.73079
# [Episode 695]  Actor loss: -5.73447, Critic loss: 0.88484
# [Episode 696]  Actor loss: -3.01219, Critic loss: 0.48203
# [Episode 697]  Actor loss: -7.77004, Critic loss: 1.19361
# [Episode 698]  Actor loss: -7.62409, Critic loss: 0.43371
# [Episode 699]  Actor loss: -4.37476, Critic loss: 0.77712
# [Episode 700]  Actor loss: -7.55515, Critic loss: 0.89120
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 701]  Actor loss: -9.88773, Critic loss: 2.27533
# [Episode 702]  Actor loss: 0.14014, Critic loss: 1.77206
# [Episode 703]  Actor loss: 2.32772, Critic loss: 0.50751
# [Episode 704]  Actor loss: 1.40002, Critic loss: 0.68959
# [Episode 705]  Actor loss: -4.44567, Critic loss: 0.46145
# [Episode 706]  Actor loss: -4.93240, Critic loss: 0.32995
# [Episode 707]  Actor loss: -4.45441, Critic loss: 0.30796
# [Episode 708]  Actor loss: -11.86215, Critic loss: 0.58790
# [Episode 709]  Actor loss: -2.93109, Critic loss: 0.52341
# [Episode 710]  Actor loss: -9.14492, Critic loss: 1.75147
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 711]  Actor loss: 1.59595, Critic loss: 0.69705
# [Episode 712]  Actor loss: -6.51422, Critic loss: 0.82450
# [Episode 713]  Actor loss: -10.97999, Critic loss: 1.32082
# [Episode 714]  Actor loss: -7.35532, Critic loss: 1.36129
# [Episode 715]  Actor loss: -11.37422, Critic loss: 2.30630
# [Episode 716]  Actor loss: -10.28556, Critic loss: 1.37073
# [Episode 717]  Actor loss: -11.09935, Critic loss: 1.83233
# [Episode 718]  Actor loss: -2.83293, Critic loss: 1.52727
# [Episode 719]  Actor loss: 0.48130, Critic loss: 1.61706
# [Episode 720]  Actor loss: -8.37992, Critic loss: 1.60553
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 721]  Actor loss: -7.63145, Critic loss: 1.98596
# [Episode 722]  Actor loss: 1.46518, Critic loss: 0.77483
# [Episode 723]  Actor loss: -5.43879, Critic loss: 1.57298
# [Episode 724]  Actor loss: -0.31003, Critic loss: 0.58731
# [Episode 725]  Actor loss: -12.23552, Critic loss: 1.05840
# [Episode 726]  Actor loss: -3.05342, Critic loss: 0.42681
# [Episode 727]  Actor loss: -5.98873, Critic loss: 0.88218
# [Episode 728]  Actor loss: -3.73277, Critic loss: 0.96143
# [Episode 729]  Actor loss: -4.96229, Critic loss: 1.49463
# [Episode 730]  Actor loss: -6.97593, Critic loss: 0.69550
# Test average reward is -5.0, Current best average reward is -4.0
#
# [Episode 731]  Actor loss: -4.37253, Critic loss: 1.56628
# [Episode 732]  Actor loss: -3.69492, Critic loss: 0.67001
# [Episode 733]  Actor loss: -4.30923, Critic loss: 1.44959
# ...
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1821]  Actor loss: -20.40512, Critic loss: 5.82413
# [Episode 1822]  Actor loss: -3.01914, Critic loss: 2.49818
# [Episode 1823]  Actor loss: -23.44397, Critic loss: 4.21766
# [Episode 1824]  Actor loss: -0.07064, Critic loss: 10.99356
# [Episode 1825]  Actor loss: 7.26490, Critic loss: 8.70063
# [Episode 1826]  Actor loss: 3.51835, Critic loss: 7.76453
# [Episode 1827]  Actor loss: 0.26923, Critic loss: 6.28754
# [Episode 1828]  Actor loss: 9.80159, Critic loss: 10.45962
# [Episode 1829]  Actor loss: -3.88162, Critic loss: 11.31199
# [Episode 1830]  Actor loss: -5.72323, Critic loss: 7.30659
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1831]  Actor loss: -15.77912, Critic loss: 5.76204
# [Episode 1832]  Actor loss: -8.78458, Critic loss: 4.83618
# [Episode 1833]  Actor loss: -1.36043, Critic loss: 6.82871
# [Episode 1834]  Actor loss: 4.19579, Critic loss: 4.21537
# [Episode 1835]  Actor loss: -21.41292, Critic loss: 6.60977
# [Episode 1836]  Actor loss: -8.46054, Critic loss: 6.07344
# [Episode 1837]  Actor loss: -11.83208, Critic loss: 5.45882
# [Episode 1838]  Actor loss: -13.58771, Critic loss: 3.94509
# [Episode 1839]  Actor loss: -10.24747, Critic loss: 5.80661
# [Episode 1840]  Actor loss: 1.47010, Critic loss: 3.80999
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1841]  Actor loss: 12.45216, Critic loss: 6.39792
# [Episode 1842]  Actor loss: 18.43161, Critic loss: 3.98841
# [Episode 1843]  Actor loss: 4.26035, Critic loss: 4.94067
# [Episode 1844]  Actor loss: 8.20188, Critic loss: 1.96194
# [Episode 1845]  Actor loss: -13.06164, Critic loss: 3.12691
# [Episode 1846]  Actor loss: -5.20464, Critic loss: 4.92605
# [Episode 1847]  Actor loss: -13.55011, Critic loss: 3.61348
# [Episode 1848]  Actor loss: -17.42293, Critic loss: 2.97008
# [Episode 1849]  Actor loss: -17.26769, Critic loss: 6.27813
# [Episode 1850]  Actor loss: -4.98727, Critic loss: 6.06317
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1851]  Actor loss: -0.37356, Critic loss: 3.27255
# [Episode 1852]  Actor loss: -26.33200, Critic loss: 4.65300
# [Episode 1853]  Actor loss: -8.11789, Critic loss: 2.70212
# [Episode 1854]  Actor loss: -13.09190, Critic loss: 4.11562
# [Episode 1855]  Actor loss: -13.05440, Critic loss: 3.31745
# [Episode 1856]  Actor loss: 3.00611, Critic loss: 5.25534
# [Episode 1857]  Actor loss: -10.06078, Critic loss: 4.17747
# [Episode 1858]  Actor loss: -8.89916, Critic loss: 6.62107
# [Episode 1859]  Actor loss: 13.31169, Critic loss: 3.76927
# [Episode 1860]  Actor loss: 4.58959, Critic loss: 2.14612
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1861]  Actor loss: -1.95132, Critic loss: 3.58830
# [Episode 1862]  Actor loss: 2.79142, Critic loss: 2.59009
# [Episode 1863]  Actor loss: -22.28007, Critic loss: 3.54098
# [Episode 1864]  Actor loss: -4.32773, Critic loss: 3.71261
# [Episode 1865]  Actor loss: -12.89675, Critic loss: 3.10495
# [Episode 1866]  Actor loss: -33.44549, Critic loss: 2.42225
# [Episode 1867]  Actor loss: -10.88684, Critic loss: 3.34116
# [Episode 1868]  Actor loss: -2.29209, Critic loss: 3.14348
# [Episode 1869]  Actor loss: -8.99060, Critic loss: 2.21724
# [Episode 1870]  Actor loss: -23.17132, Critic loss: 4.29909
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1871]  Actor loss: -15.85516, Critic loss: 5.78132
# [Episode 1872]  Actor loss: -10.97498, Critic loss: 4.37679
# [Episode 1873]  Actor loss: 15.40333, Critic loss: 5.63472
# [Episode 1874]  Actor loss: -3.25564, Critic loss: 3.04571
# [Episode 1875]  Actor loss: -13.64596, Critic loss: 6.68700
# [Episode 1876]  Actor loss: 11.55969, Critic loss: 3.21743
# [Episode 1877]  Actor loss: -3.71183, Critic loss: 2.98639
# [Episode 1878]  Actor loss: 0.55735, Critic loss: 3.50074
# [Episode 1879]  Actor loss: -1.47339, Critic loss: 1.81326
# [Episode 1880]  Actor loss: -11.03098, Critic loss: 3.14114
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1881]  Actor loss: -25.35444, Critic loss: 3.60078
# [Episode 1882]  Actor loss: -16.86584, Critic loss: 5.17835
# [Episode 1883]  Actor loss: -1.48319, Critic loss: 3.40665
# [Episode 1884]  Actor loss: -0.79649, Critic loss: 4.93677
# [Episode 1885]  Actor loss: -21.40094, Critic loss: 5.61491
# [Episode 1886]  Actor loss: 12.76835, Critic loss: 4.93317
# [Episode 1887]  Actor loss: -6.09603, Critic loss: 4.03489
# [Episode 1888]  Actor loss: 1.26862, Critic loss: 1.69765
# [Episode 1889]  Actor loss: -20.82577, Critic loss: 4.85926
# [Episode 1890]  Actor loss: -39.71422, Critic loss: 2.77991
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1891]  Actor loss: -15.94205, Critic loss: 3.08495
# [Episode 1892]  Actor loss: -18.87649, Critic loss: 2.92287
# [Episode 1893]  Actor loss: -18.05626, Critic loss: 2.91294
# [Episode 1894]  Actor loss: -4.45827, Critic loss: 5.25323
# [Episode 1895]  Actor loss: 3.06736, Critic loss: 5.82621
# [Episode 1896]  Actor loss: -16.91895, Critic loss: 3.55272
# [Episode 1897]  Actor loss: -32.10743, Critic loss: 3.94049
# [Episode 1898]  Actor loss: -12.38238, Critic loss: 7.53907
# [Episode 1899]  Actor loss: 2.45552, Critic loss: 5.65749
# [Episode 1900]  Actor loss: 5.53223, Critic loss: 6.57423
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1901]  Actor loss: 20.87225, Critic loss: 5.42384
# [Episode 1902]  Actor loss: -0.34677, Critic loss: 3.17974
# [Episode 1903]  Actor loss: 5.83902, Critic loss: 4.41180
# [Episode 1904]  Actor loss: -2.18344, Critic loss: 3.27389
# [Episode 1905]  Actor loss: -17.01405, Critic loss: 4.33860
# [Episode 1906]  Actor loss: 1.74761, Critic loss: 3.12665
# [Episode 1907]  Actor loss: -11.09660, Critic loss: 6.43908
# [Episode 1908]  Actor loss: -13.33446, Critic loss: 2.96195
# [Episode 1909]  Actor loss: -4.05728, Critic loss: 7.01925
# [Episode 1910]  Actor loss: -4.81687, Critic loss: 3.27782
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1911]  Actor loss: -9.33255, Critic loss: 2.99885
# [Episode 1912]  Actor loss: -14.22181, Critic loss: 4.30234
# [Episode 1913]  Actor loss: -28.01688, Critic loss: 4.41277
# [Episode 1914]  Actor loss: -16.01184, Critic loss: 5.15236
# [Episode 1915]  Actor loss: -5.74110, Critic loss: 1.91979
# [Episode 1916]  Actor loss: -25.77808, Critic loss: 5.90972
# [Episode 1917]  Actor loss: 6.01700, Critic loss: 5.38333
# [Episode 1918]  Actor loss: -36.33718, Critic loss: 4.36418
# [Episode 1919]  Actor loss: -10.47133, Critic loss: 4.68593
# [Episode 1920]  Actor loss: 2.65475, Critic loss: 9.08602
# Test average reward is -5.0, Current best average reward is -2.0
#
# [Episode 1921]  Actor loss: 0.69803, Critic loss: 4.50829
# [Episode 1922]  Actor loss: 2.66687, Critic loss: 2.46098
# [Episode 1923]  Actor loss: -0.00604, Critic loss: 6.02155
# [Episode 1924]  Actor loss: -15.89219, Critic loss: 4.03951
# [Episode 1925]  Actor loss: -14.44323, Critic loss: 5.35411
# [Episode 1926]  Actor loss: -12.37814, Critic loss: 7.10154
# [Episode 1927]  Actor loss: 2.72604, Critic loss: 7.19539
# [Episode 1928]  Actor loss: 18.98805, Critic loss: 10.82386
# [Episode 1929]  Actor loss: 7.75336, Critic loss: 8.99178
# [Episode 1930]  Actor loss: 5.01005, Critic loss: 6.66136
# Test average reward is 0.0, Current best average reward is -2.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_1930_0.0\assets
# [Episode 1931]  Actor loss: 5.79714, Critic loss: 3.05936
# [Episode 1932]  Actor loss: -8.02557, Critic loss: 4.70457
# [Episode 1933]  Actor loss: -6.17719, Critic loss: 2.95334
# [Episode 1934]  Actor loss: 12.77384, Critic loss: 3.10821
# [Episode 1935]  Actor loss: -35.27280, Critic loss: 5.40776
# [Episode 1936]  Actor loss: -13.71025, Critic loss: 7.85323
# [Episode 1937]  Actor loss: -14.69422, Critic loss: 3.16100
# [Episode 1938]  Actor loss: -10.99751, Critic loss: 4.15902
# [Episode 1939]  Actor loss: -3.53752, Critic loss: 3.99199
# [Episode 1940]  Actor loss: -12.04495, Critic loss: 5.12797
# Test average reward is -5.0, Current best average reward is 0.0
#
# [Episode 1941]  Actor loss: 2.58427, Critic loss: 4.93329
# [Episode 1942]  Actor loss: 10.81169, Critic loss: 4.27350
# [Episode 1943]  Actor loss: -0.48013, Critic loss: 4.61593
# [Episode 1944]  Actor loss: -20.72427, Critic loss: 5.63451
# [Episode 1945]  Actor loss: 12.74132, Critic loss: 3.93664
# [Episode 1946]  Actor loss: -14.98668, Critic loss: 4.81253
# [Episode 1947]  Actor loss: -12.63154, Critic loss: 2.95993
# [Episode 1948]  Actor loss: -21.03692, Critic loss: 4.13433
# [Episode 1949]  Actor loss: -23.44470, Critic loss: 6.51189
# [Episode 1950]  Actor loss: 2.53386, Critic loss: 5.58384
# Test average reward is 2.0, Current best average reward is 0.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_1950_2.0\assets
# [Episode 1951]  Actor loss: 9.41513, Critic loss: 3.34499
# [Episode 1952]  Actor loss: -10.68672, Critic loss: 2.75058
# [Episode 1953]  Actor loss: -6.48056, Critic loss: 8.12888
# [Episode 1954]  Actor loss: -3.60144, Critic loss: 5.11316
# [Episode 1955]  Actor loss: 12.43290, Critic loss: 3.03828
# [Episode 1956]  Actor loss: -13.59216, Critic loss: 3.61646
# [Episode 1957]  Actor loss: -6.55414, Critic loss: 3.40810
# [Episode 1958]  Actor loss: -7.25370, Critic loss: 3.10434
# [Episode 1959]  Actor loss: -4.72396, Critic loss: 2.00001
# [Episode 1960]  Actor loss: -11.53978, Critic loss: 1.92585
# Test average reward is -5.0, Current best average reward is 2.0
#
# [Episode 1961]  Actor loss: -26.20649, Critic loss: 2.16288
# [Episode 1962]  Actor loss: -14.37814, Critic loss: 4.18965
# [Episode 1963]  Actor loss: 1.35621, Critic loss: 4.68234
# [Episode 1964]  Actor loss: -14.73653, Critic loss: 2.68051
# [Episode 1965]  Actor loss: -10.35945, Critic loss: 7.14152
# [Episode 1966]  Actor loss: -26.14009, Critic loss: 4.66841
# [Episode 1967]  Actor loss: -31.96527, Critic loss: 3.74880
# [Episode 1968]  Actor loss: -5.72099, Critic loss: 2.49681
# [Episode 1969]  Actor loss: -4.68374, Critic loss: 2.45554
# [Episode 1970]  Actor loss: -23.25057, Critic loss: 4.24530
# Test average reward is -1.0, Current best average reward is 2.0
#
# [Episode 1971]  Actor loss: 22.09667, Critic loss: 5.25506
# [Episode 1972]  Actor loss: -19.17663, Critic loss: 6.91816
# [Episode 1973]  Actor loss: -11.52251, Critic loss: 3.54703
# [Episode 1974]  Actor loss: 7.63548, Critic loss: 3.76453
# [Episode 1975]  Actor loss: -6.96388, Critic loss: 4.02535
# [Episode 1976]  Actor loss: -4.50702, Critic loss: 8.04963
# [Episode 1977]  Actor loss: -13.64331, Critic loss: 6.65780
# [Episode 1978]  Actor loss: -20.92130, Critic loss: 6.02867
# [Episode 1979]  Actor loss: 1.14343, Critic loss: 8.99867
# [Episode 1980]  Actor loss: -26.86669, Critic loss: 6.03515
# Test average reward is -5.0, Current best average reward is 2.0
#
# [Episode 1981]  Actor loss: -6.42046, Critic loss: 8.20685
# [Episode 1982]  Actor loss: 9.85771, Critic loss: 3.41896
# [Episode 1983]  Actor loss: -6.79503, Critic loss: 8.35912
# [Episode 1984]  Actor loss: -16.20559, Critic loss: 5.71636
# [Episode 1985]  Actor loss: -7.61556, Critic loss: 6.12037
# [Episode 1986]  Actor loss: 0.24914, Critic loss: 7.33309
# [Episode 1987]  Actor loss: -3.36151, Critic loss: 3.53027
# [Episode 1988]  Actor loss: -11.13511, Critic loss: 4.95623
# [Episode 1989]  Actor loss: 7.39016, Critic loss: 5.21861
# [Episode 1990]  Actor loss: 2.30536, Critic loss: 2.55533
# Test average reward is -5.0, Current best average reward is 2.0
#
# [Episode 1991]  Actor loss: -9.57564, Critic loss: 6.07798
# [Episode 1992]  Actor loss: -33.07454, Critic loss: 4.25815
# [Episode 1993]  Actor loss: -1.82369, Critic loss: 6.65754
# [Episode 1994]  Actor loss: -4.62109, Critic loss: 5.44218
# [Episode 1995]  Actor loss: -18.08090, Critic loss: 5.10972
# [Episode 1996]  Actor loss: -5.49811, Critic loss: 5.62757
# [Episode 1997]  Actor loss: 20.62466, Critic loss: 5.04934
# [Episode 1998]  Actor loss: 9.35364, Critic loss: 3.59386
# [Episode 1999]  Actor loss: 8.06200, Critic loss: 3.96794
# [Episode 2000]  Actor loss: -6.25152, Critic loss: 2.98073
# Test average reward is -5.0, Current best average reward is 2.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_2000_-5.0\assets
# Moviepy - Building video movie_f/Lab15_demo-2000.webm.
# Moviepy - Writing video movie_f/Lab15_demo-2000.webm
# Moviepy - Done !
# Moviepy - video ready movie_f/Lab15_demo-2000.webm
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video autoplay='1' loop='1'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# [Episode 2001]  Actor loss: -16.79783, Critic loss: 3.66185
# [Episode 2002]  Actor loss: -12.37404, Critic loss: 2.55379
# [Episode 2003]  Actor loss: -8.17080, Critic loss: 2.16940
# [Episode 2004]  Actor loss: -17.60952, Critic loss: 2.61466
# [Episode 2005]  Actor loss: -12.11849, Critic loss: 4.20179
# [Episode 2006]  Actor loss: -17.79030, Critic loss: 2.14000
# [Episode 2007]  Actor loss: -10.17881, Critic loss: 5.88368
# [Episode 2008]  Actor loss: -9.77929, Critic loss: 5.07131
# [Episode 2009]  Actor loss: -14.23838, Critic loss: 10.07444
# [Episode 2010]  Actor loss: 11.69010, Critic loss: 5.54216
# Test average reward is -5.0, Current best average reward is 2.0
#
# [Episode 2011]  Actor loss: 11.29829, Critic loss: 7.48804
# [Episode 2012]  Actor loss: 7.76369, Critic loss: 2.96006
# [Episode 2013]  Actor loss: -21.31937, Critic loss: 3.58374
# [Episode 2014]  Actor loss: -14.35164, Critic loss: 5.56582
# [Episode 2015]  Actor loss: -4.55442, Critic loss: 3.17529
# [Episode 2016]  Actor loss: -8.72077, Critic loss: 5.40878
# [Episode 2017]  Actor loss: -31.72330, Critic loss: 4.76754
# [Episode 2018]  Actor loss: -20.68990, Critic loss: 6.95017
# [Episode 2019]  Actor loss: 4.54508, Critic loss: 5.16785
# [Episode 2020]  Actor loss: -10.93597, Critic loss: 3.94690
# Test average reward is -5.0, Current best average reward is 2.0
#
# [Episode 2021]  Actor loss: 10.11252, Critic loss: 6.93887
# [Episode 2022]  Actor loss: -3.01659, Critic loss: 3.94532
# [Episode 2023]  Actor loss: -12.33526, Critic loss: 7.40382
# [Episode 2024]  Actor loss: -2.47143, Critic loss: 4.41444
# [Episode 2025]  Actor loss: -0.90574, Critic loss: 6.36346
# [Episode 2026]  Actor loss: -11.30333, Critic loss: 4.20609
# [Episode 2027]  Actor loss: 2.63524, Critic loss: 4.19961
# [Episode 2028]  Actor loss: -6.74828, Critic loss: 2.66430
# [Episode 2029]  Actor loss: -3.13139, Critic loss: 4.63346
# [Episode 2030]  Actor loss: 3.94130, Critic loss: 3.49806
# Test average reward is -5.0, Current best average reward is 2.0
#
# [Episode 2031]  Actor loss: -2.18830, Critic loss: 4.51785
# [Episode 2032]  Actor loss: 0.87120, Critic loss: 3.85959
# [Episode 2033]  Actor loss: -16.22470, Critic loss: 3.13744
# [Episode 2034]  Actor loss: -13.77110, Critic loss: 2.86798
# [Episode 2035]  Actor loss: -13.75348, Critic loss: 3.90484
# [Episode 2036]  Actor loss: -16.17551, Critic loss: 5.43699
# [Episode 2037]  Actor loss: 0.60038, Critic loss: 2.80654
# [Episode 2038]  Actor loss: 7.77779, Critic loss: 4.25123
# [Episode 2039]  Actor loss: -12.42336, Critic loss: 4.17807
# [Episode 2040]  Actor loss: -6.01506, Critic loss: 4.69975
# Test average reward is -5.0, Current best average reward is 2.0
#
# [Episode 2041]  Actor loss: -17.87802, Critic loss: 2.32872
# [Episode 2042]  Actor loss: 1.57922, Critic loss: 2.70563
# [Episode 2043]  Actor loss: -15.47942, Critic loss: 4.41182
# [Episode 2044]  Actor loss: -16.51398, Critic loss: 5.62626
# [Episode 2045]  Actor loss: -26.90884, Critic loss: 4.55937
# [Episode 2046]  Actor loss: -17.86029, Critic loss: 4.97395
# [Episode 2047]  Actor loss: -8.92514, Critic loss: 3.59187
# [Episode 2048]  Actor loss: 1.95618, Critic loss: 9.46923
# [Episode 2049]  Actor loss: -27.75409, Critic loss: 4.16470
# [Episode 2050]  Actor loss: -11.25077, Critic loss: 3.91795
# Test average reward is 26.0, Current best average reward is 2.0
#
# INFO:tensorflow:Assets written to: ./save/Actor/model_actor_2050_26.0\assets

# %% [markdown]
# # Report
#
# 我在第2050個Episode時，Test average reward超過early_stop_reward，也就是10，來到了 26 Test average reward。
#
# 在現實環境當中，有非常多的state跟action，要計算並儲存全部的state-action pairs是不現實的。因此需要理deep reinforcement learninge來evalutate value或action。在這個lab主要在實作GAE與PPO，以下會依照我的理解講解:
#
#
# ## GAE
# 首先是GAE，GAE是一種用來優化reward的方法。使用GAE不只可以看到近期的reward，也可以看到長期的reward，也就是說即使執行action不能立即獲得好的reward，多走幾步之後就可以獲得reward。在**compute_gae( )**這個function中:
# 1. 首先會先定義delta(會考慮discount)
# 2. 並再用delta去更新GAE
# 3. 最後再拿更新好的GAE加上reward而得到reward
# 4. 最後的return值要reverse，是因為我們是先從最後的time stamp開始計算，因此在return前，要先reverse。
#
# ## PPO
# PPO是一種優化loss function的方法，根據paper，有些model一但學習到不好的Policy，他之後就只會產生出不好的action，因此無法幫助Policy進步，PPO試著解決這樣的問題。PPO會讓policy在更新的時候，只走一小步，因此可以穩定訓練過程。在**ppo_update( )**中：
# 1. 首先會計算ratio，代表policy改變的多寡，並經過log
# 2. 並利用ratio去計算surr1與surr2，再取當中的最小值，去計算**actor loss**
# 3. 並利用MSE去計算reward, value的差異，並以此當做**critical loss**
# 4. 最後再actor loss與critical loss做相加，當作total loss
